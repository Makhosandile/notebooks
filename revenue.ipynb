# %%
import numpy as np
import pandas as pd

# %%
deficit_df = pd.read_csv("revenue.csv")

# %%
def customs_and_other_import_duties_perc_tax_revenue():
    """Customs and other import duties (% of tax revenue) [GC.TAX.IMPT.ZS]"""
    df = deficit_df[["year", "country", "customs_and_other_import_duties_perc_tax_revenue"]]
    return df

# %%
customs_and_other_import_duties_perc_tax_revenue()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        customs_and_other_import_duties_perc_tax_revenue
# 0                                                   NaN
# 1                                                   NaN
# ...

# %%
def customs_and_other_import_duties_currentLCU():
    """Customs and other import duties (current LCU) [GC.TAX.IMPT.CN]"""
    df = deficit_df[["year", "country", "customs_and_other_import_duties_currentLCU"]]
    return df

# %%
customs_and_other_import_duties_currentLCU()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        customs_and_other_import_duties_currentLCU
# 0                                             NaN
# 1                                             NaN
# ...

# %%
def grants_and_other_revenue_perc_revenue():
    """Grants and other revenue (% of revenue) [GC.REV.GOTR.ZS]"""
    df = deficit_df[["year", "country", "grants_and_other_revenue_perc_revenue"]]
    return df

# %%
grants_and_other_revenue_perc_revenue()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        grants_and_other_revenue_perc_revenue
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# ...

# %%
def grants_and_other_revenue_currentLCU():
    """Grants and other revenue (current LCU) [GC.REV.GOTR.CN]"""
    df = deficit_df[["year", "country", "grants_and_other_revenue_currentLCU"]]
    return df

# %%
grants_and_other_revenue_currentLCU()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        grants_and_other_revenue_currentLCU
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# ...

# %%
def other_taxes_perc_revenue():
    """Other taxes (% of revenue) [GC.TAX.OTHR.RV.ZS]"""
    df = deficit_df[["year", "country", "other_taxes_perc_revenue"]]
    return df

# %%
other_taxes_perc_revenue()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        other_taxes_perc_revenue
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# ...

# %%
def other_taxes_currentLCU():
    """Other taxes (current LCU) [GC.TAX.OTHR.CN]"""
    df = deficit_df[["year", "country", "other_taxes_currentLCU"]]
    return df

# %%
other_taxes_currentLCU()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        other_taxes_currentLCU
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...

# %%
def revenue_excluding_grants_percGDP():
    """IRevenue, excluding grants (% of GDP) [GC.REV.XGRT.GD.ZS]"""
    df = deficit_df[["year", "country", "revenue_excluding_grants_percGDP"]]
    return df

# %%
revenue_excluding_grants_percGDP()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        revenue_excluding_grants_percGDP
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# ...

# %%
def revenue_excluding_grants_currentLCU():
    """IRevenue, excluding grants (current LCU) [GC.REV.XGRT.CN]"""
    df = deficit_df[["year", "country", "revenue_excluding_grants_currentLCU"]]
    return df

# %%
revenue_excluding_grants_currentLCU()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        revenue_excluding_grants_currentLCU
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# ...

# %%
def social_contributions_perc_revenue():
    """Social contributions (% of revenue) [GC.REV.SOCL.ZS]"""
    df = deficit_df[["year", "country", "social_contributions_perc_revenue"]]
    return df

# %%
social_contributions_perc_revenue()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        social_contributions_perc_revenue
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# ...

# %%
def social_contributions_currentLCU():
    """Social contributions (current LCU) [GC.REV.SOCL.CN]"""
    df = deficit_df[["year", "country", "social_contributions_currentLCU"]]
    return df

# %%
social_contributions_currentLCU()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        social_contributions_currentLCU
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# ...

# %%
def tax_revenue_percGDP():
    """Tax revenue (% of GDP) [GC.TAX.TOTL.GD.ZS]"""
    df = deficit_df[["year", "country", "tax_revenue_percGDP"]]
    return df

# %%
tax_revenue_percGDP()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        tax_revenue_percGDP
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# ...

# %%
def tax_revenue_currentLCU():
    """Tax revenue (current LCU) [GC.TAX.TOTL.CN]"""
    df = deficit_df[["year", "country", "tax_revenue_currentLCU"]]
    return df

# %%
tax_revenue_currentLCU()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        tax_revenue_currentLCU
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...

# %%
def taxes_on_exports_perc_revenue():
    """Taxes on exports (% of tax revenue) [GC.TAX.EXPT.ZS]"""
    df = deficit_df[["year", "country", "taxes_on_exports_perc_revenue"]]
    return df

# %%
taxes_on_exports_perc_revenue()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        taxes_on_exports_perc_revenue
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# ...

# %%
def taxes_on_exports_currentLCU():
    """Taxes on exports (current LCU) [GC.TAX.EXPT.CN]"""
    df = deficit_df[["year", "country", "taxes_on_exports_currentLCU"]]
    return df

# %%
taxes_on_exports_currentLCU()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        taxes_on_exports_currentLCU
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# ...

# %%
def taxes_on_goods_and_services_perc_revenue():
    """Taxes on goods and services (% of revenue) [GC.TAX.GSRV.RV.ZS]"""
    df = deficit_df[["year", "country", "taxes_on_goods_and_services_perc_revenue"]]
    return df

# %%
taxes_on_goods_and_services_perc_revenue()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        taxes_on_goods_and_services_perc_revenue
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# ...

# %%
def taxes_on_goods_and_services_perc_value_added_of_industry_and_services():
    """Taxes on goods and services (% value added of industry and services) [GC.TAX.GSRV.VA.ZS]"""
    df = deficit_df[["year", "country", "taxes_on_goods_and_services_perc_value_added_of_industry_and_services"]]
    return df

# %%
taxes_on_goods_and_services_perc_value_added_of_industry_and_services()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        taxes_on_goods_and_services_perc_value_added_of_industry_and_services
# 0                                                    NaN
# 1                                                    NaN
# ...

# %%
def taxes_on_goods_and_services_currentLCU():
    """Taxes on goods and services (current LCU) [GC.TAX.GSRV.CN]"""
    df = deficit_df[["year", "country", "taxes_on_goods_and_services_currentLCU"]]
    return df

# %%
taxes_on_goods_and_services_currentLCU()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        taxes_on_goods_and_services_currentLCU
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# ...

# %%
def taxes_on_income_profits_and_capital_gains_perc_revenue():
    """Taxes on income, profits and capital gains (% of revenue) [GC.TAX.YPKG.RV.ZS]"""
    df = deficit_df[["year", "country", "taxes_on_income_profits_and_capital_gains_perc_revenue"]]
    return df

# %%
taxes_on_income_profits_and_capital_gains_perc_revenue()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        taxes_on_income_profits_and_capital_gains_perc_revenue
# 0                                                    NaN
# 1                                                    NaN
# ...

# %%
def taxes_on_income_profits_and_capital_gains_perc_total_taxes():
    """Taxes on income, profits and capital gains (% of total taxes) [GC.TAX.YPKG.ZS]"""
    df = deficit_df[["year", "country", "taxes_on_income_profits_and_capital_gains_perc_total_taxes"]]
    return df

# %%
taxes_on_income_profits_and_capital_gains_perc_total_taxes()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        taxes_on_income_profits_and_capital_gains_perc_total_taxes
# 0                                                    NaN
# 1                                                    NaN
# ...

# %%
def taxes_on_income_profits_and_capital_gains_currentLCU():
    """Taxes on income, profits and capital gains (current LCU) [GC.TAX.YPKG.CN]"""
    df = deficit_df[["year", "country", "taxes_on_income_profits_and_capital_gains_currentLCU"]]
    return df

# %%
taxes_on_income_profits_and_capital_gains_currentLCU()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        taxes_on_income_profits_and_capital_gains_currentLCU
# 0                                                    NaN
# 1                                                    NaN
# ...

# %%
def taxes_on_international_trade_perc_revenue():
    """Taxes on international trade (% of revenue) [GC.TAX.INTT.RV.ZS]"""
    df = deficit_df[["year", "country", "taxes_on_international_trade_perc_revenue"]]
    return df

# %%
taxes_on_international_trade_perc_revenue()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        taxes_on_international_trade_perc_revenue
# 0                                            NaN
# 1                                            NaN
# ...

# %%
def taxes_on_exports_perc_revenue():
    """Taxes on exports (% of tax revenue) [GC.TAX.EXPT.ZS]"""
    df = deficit_df[["year", "country", "taxes_on_exports_perc_revenue"]]
    return df
