# %%
import pandas as pd
import numpy as np
from operator import getitem
from functools import partial

# %%
df = pd.read_json('c.json')
df
# Out:
#       id                       name iso3 iso2 phone_code    capital currency  \
# 0      1                Afghanistan  AFG   AF         93      Kabul      AFN
# 1      2              Aland Islands  ALA   AX    +358-18  Mariehamn      EUR
# 2      3                    Albania  ALB   AL        355     Tirana      ALL
# 3      4                    Algeria  DZA   DZ        213    Algiers      DZD
# 4      5             American Samoa  ASM   AS     +1-684  Pago Pago      USD
# ..   ...                        ...  ...  ...        ...        ...      ...
# 245  243  Wallis And Futuna Islands  WLF   WF        681   Mata Utu      XPF
# 246  244             Western Sahara  ESH   EH        212   El-Aaiun      MAD
# 247  245                      Yemen  YEM   YE        967      Sanaa      YER
# 248  246                     Zambia  ZMB   ZM        260     Lusaka      ZMW
# 249  247                   Zimbabwe  ZWE   ZW        263     Harare      ZWL
#
#     currency_symbol  tld            native   region        subregion  \
# 0                 ؋  .af         افغانستان     Asia    Southern Asia
# 1                 €  .ax             Åland   Europe  Northern Europe
# 2               Lek  .al         Shqipëria   Europe  Southern Europe
# 3                دج  .dz           الجزائر   Africa  Northern Africa
# 4                 $  .as    American Samoa  Oceania        Polynesia
# ..              ...  ...               ...      ...              ...
# 245               ₣  .wf  Wallis et Futuna  Oceania        Polynesia
# 246             MAD  .eh   الصحراء الغربية   Africa  Northern Africa
# 247               ﷼  .ye           اليَمَن     Asia     Western Asia
# 248              ZK  .zm            Zambia   Africa   Eastern Africa
# 249               $  .zw          Zimbabwe   Africa   Eastern Africa
#
#                                              timezones  \
# 0    [{'zoneName': 'Asia/Kabul', 'gmtOffset': 16200...
# 1    [{'zoneName': 'Europe/Mariehamn', 'gmtOffset':...
# 2    [{'zoneName': 'Europe/Tirane', 'gmtOffset': 36...
# 3    [{'zoneName': 'Africa/Algiers', 'gmtOffset': 3...
# 4    [{'zoneName': 'Pacific/Pago_Pago', 'gmtOffset'...
# ..                                                 ...
# 245  [{'zoneName': 'Pacific/Wallis', 'gmtOffset': 4...
# 246  [{'zoneName': 'Africa/El_Aaiun', 'gmtOffset': ...
# 247  [{'zoneName': 'Asia/Aden', 'gmtOffset': 10800,...
# 248  [{'zoneName': 'Africa/Lusaka', 'gmtOffset': 72...
# 249  [{'zoneName': 'Africa/Harare', 'gmtOffset': 72...
#
#                                           translations   latitude  longitude  \
# 0    {'br': 'Afeganistão', 'pt': 'Afeganistão', 'nl...  33.000000       65.0
# 1    {'br': 'Ilhas de Aland', 'pt': 'Ilhas de Aland...  60.116667       19.9
# 2    {'br': 'Albânia', 'pt': 'Albânia', 'nl': 'Alba...  41.000000       20.0
# 3    {'br': 'Argélia', 'pt': 'Argélia', 'nl': 'Alge...  28.000000        3.0
# 4    {'br': 'Samoa Americana', 'pt': 'Samoa America... -14.333333     -170.0
# ..                                                 ...        ...        ...
# 245  {'br': 'Wallis e Futuna', 'pt': 'Wallis e Futu... -13.300000     -176.2
# 246  {'br': 'Saara Ocidental', 'pt': 'Saara Ocident...  24.500000      -13.0
# 247  {'br': 'Iêmen', 'pt': 'Iémen', 'nl': 'Jemen', ...  15.000000       48.0
# 248  {'br': 'Zâmbia', 'pt': 'Zâmbia', 'nl': 'Zambia... -15.000000       30.0
# 249  {'br': 'Zimbabwe', 'pt': 'Zimbabué', 'nl': 'Zi... -20.000000       30.0
#
#     emoji           emojiU                                             states
# 0      🇦🇫  U+1F1E6 U+1F1EB  [{'id': 3901, 'name': 'Badakhshan', 'state_cod...
# 1      🇦🇽  U+1F1E6 U+1F1FD                                                 []
# 2      🇦🇱  U+1F1E6 U+1F1F1  [{'id': 603, 'name': 'Berat County', 'state_co...
# 3      🇩🇿  U+1F1E9 U+1F1FF  [{'id': 1118, 'name': 'Adrar', 'state_code': '...
# 4      🇦🇸  U+1F1E6 U+1F1F8                                                 []
# ..    ...              ...                                                ...
# 245    🇼🇫  U+1F1FC U+1F1EB                                                 []
# 246    🇪🇭  U+1F1EA U+1F1ED                                                 []
# 247    🇾🇪  U+1F1FE U+1F1EA  [{'id': 1242, 'name': ''Adan Governorate', 'st...
# 248    🇿🇲  U+1F1FF U+1F1F2  [{'id': 1986, 'name': 'Central Province', 'sta...
# 249    🇿🇼  U+1F1FF U+1F1FC  [{'id': 1956, 'name': 'Bulawayo Province', 'st...
#
# [250 rows x 19 columns]

# %%
df = pd.read_json('c.json')
df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id'], axis = 1)
df.head(50)
# Out:
#                                 name iso3 iso2 phone_code  \
# 0                        Afghanistan  AFG   AF         93
# 1                      Aland Islands  ALA   AX    +358-18
# 2                            Albania  ALB   AL        355
# 3                            Algeria  DZA   DZ        213
# 4                     American Samoa  ASM   AS     +1-684
# 5                            Andorra  AND   AD        376
# 6                             Angola  AGO   AO        244
# 7                           Anguilla  AIA   AI     +1-264
# 8                         Antarctica  ATA   AQ
# 9                Antigua And Barbuda  ATG   AG     +1-268
# 10                         Argentina  ARG   AR         54
# 11                           Armenia  ARM   AM        374
# 12                             Aruba  ABW   AW        297
# 13                         Australia  AUS   AU         61
# 14                           Austria  AUT   AT         43
# 15                        Azerbaijan  AZE   AZ        994
# 16                       Bahamas The  BHS   BS     +1-242
# 17                           Bahrain  BHR   BH        973
# 18                        Bangladesh  BGD   BD        880
# 19                          Barbados  BRB   BB     +1-246
# 20                           Belarus  BLR   BY        375
# 21                           Belgium  BEL   BE         32
# 22                            Belize  BLZ   BZ        501
# 23                             Benin  BEN   BJ        229
# 24                           Bermuda  BMU   BM     +1-441
# 25                            Bhutan  BTN   BT        975
# 26                           Bolivia  BOL   BO        591
# 27  Bonaire, Sint Eustatius and Saba  BES   BQ        599
# 28            Bosnia and Herzegovina  BIH   BA        387
# 29                          Botswana  BWA   BW        267
# 30                     Bouvet Island  BVT   BV       0055
# 31                            Brazil  BRA   BR         55
# 32    British Indian Ocean Territory  IOT   IO        246
# 33                            Brunei  BRN   BN        673
# 34                          Bulgaria  BGR   BG        359
# 35                      Burkina Faso  BFA   BF        226
# 36                           Burundi  BDI   BI        257
# 37                          Cambodia  KHM   KH        855
# 38                          Cameroon  CMR   CM        237
# 39                            Canada  CAN   CA          1
# 40                        Cape Verde  CPV   CV        238
# 41                    Cayman Islands  CYM   KY     +1-345
# 42          Central African Republic  CAF   CF        236
# 43                              Chad  TCD   TD        235
# 44                             Chile  CHL   CL         56
# 45                             China  CHN   CN         86
# 46                  Christmas Island  CXR   CX         61
# 47           Cocos (Keeling) Islands  CCK   CC         61
# 48                          Colombia  COL   CO         57
# 49                           Comoros  COM   KM        269
#
#                 capital currency currency_symbol    region  \
# 0                 Kabul      AFN               ؋      Asia
# 1             Mariehamn      EUR               €    Europe
# 2                Tirana      ALL             Lek    Europe
# 3               Algiers      DZD              دج    Africa
# 4             Pago Pago      USD               $   Oceania
# 5      Andorra la Vella      EUR               €    Europe
# 6                Luanda      AOA              Kz    Africa
# 7            The Valley      XCD               $  Americas
# 8                                              $     Polar
# 9            St. John's      XCD               $  Americas
# 10         Buenos Aires      ARS               $  Americas
# 11              Yerevan      AMD               ֏      Asia
# 12           Oranjestad      AWG               ƒ  Americas
# 13             Canberra      AUD               $   Oceania
# 14               Vienna      EUR               €    Europe
# 15                 Baku      AZN               m      Asia
# 16               Nassau      BSD              B$  Americas
# 17               Manama      BHD            .د.ب      Asia
# 18                Dhaka      BDT               ৳      Asia
# 19           Bridgetown      BBD            Bds$  Americas
# 20                Minsk      BYN              Br    Europe
# 21             Brussels      EUR               €    Europe
# 22             Belmopan      BZD               $  Americas
# 23           Porto-Novo      XOF             CFA    Africa
# 24             Hamilton      BMD               $  Americas
# 25              Thimphu      BTN             Nu.      Asia
# 26                Sucre      BOB             Bs.  Americas
# 27           Kralendijk      USD               $  Americas
# 28             Sarajevo      BAM              KM    Europe
# 29             Gaborone      BWP               P    Africa
# 30                           NOK              kr
# 31             Brasilia      BRL              R$  Americas
# 32         Diego Garcia      USD               $    Africa
# 33  Bandar Seri Begawan      BND              B$      Asia
# 34                Sofia      BGN             Лв.    Europe
# 35          Ouagadougou      XOF             CFA    Africa
# 36            Bujumbura      BIF             FBu    Africa
# 37           Phnom Penh      KHR             KHR      Asia
# 38              Yaounde      XAF            FCFA    Africa
# 39               Ottawa      CAD               $  Americas
# 40                Praia      CVE               $    Africa
# 41          George Town      KYD               $  Americas
# 42               Bangui      XAF            FCFA    Africa
# 43            N'Djamena      XAF            FCFA    Africa
# 44             Santiago      CLP               $  Americas
# 45              Beijing      CNY               ¥      Asia
# 46     Flying Fish Cove      AUD               $   Oceania
# 47          West Island      AUD               $   Oceania
# 48               Bogota      COP               $  Americas
# 49               Moroni      KMF              CF    Africa
#
#                     subregion   latitude   longitude emoji
# 0               Southern Asia  33.000000   65.000000    🇦🇫
# 1             Northern Europe  60.116667   19.900000    🇦🇽
# 2             Southern Europe  41.000000   20.000000    🇦🇱
# 3             Northern Africa  28.000000    3.000000    🇩🇿
# 4                   Polynesia -14.333333 -170.000000    🇦🇸
# 5             Southern Europe  42.500000    1.500000    🇦🇩
# 6               Middle Africa -12.500000   18.500000    🇦🇴
# 7                   Caribbean  18.250000  -63.166667    🇦🇮
# 8                             -74.650000    4.480000    🇦🇶
# 9                   Caribbean  17.050000  -61.800000    🇦🇬
# 10              South America -34.000000  -64.000000    🇦🇷
# 11               Western Asia  40.000000   45.000000    🇦🇲
# 12                  Caribbean  12.500000  -69.966667    🇦🇼
# 13  Australia and New Zealand -27.000000  133.000000    🇦🇺
# 14             Western Europe  47.333333   13.333333    🇦🇹
# 15               Western Asia  40.500000   47.500000    🇦🇿
# 16                  Caribbean  24.250000  -76.000000    🇧🇸
# 17               Western Asia  26.000000   50.550000    🇧🇭
# 18              Southern Asia  24.000000   90.000000    🇧🇩
# 19                  Caribbean  13.166667  -59.533333    🇧🇧
# 20             Eastern Europe  53.000000   28.000000    🇧🇾
# 21             Western Europe  50.833333    4.000000    🇧🇪
# 22            Central America  17.250000  -88.750000    🇧🇿
# 23             Western Africa   9.500000    2.250000    🇧🇯
# 24           Northern America  32.333333  -64.750000    🇧🇲
# 25              Southern Asia  27.500000   90.500000    🇧🇹
# 26              South America -17.000000  -65.000000    🇧🇴
# 27                  Caribbean  12.150000  -68.266667    🇧🇶
# 28            Southern Europe  44.000000   18.000000    🇧🇦
# 29            Southern Africa -22.000000   24.000000    🇧🇼
# 30                            -54.433333    3.400000    🇧🇻
# 31              South America -10.000000  -55.000000    🇧🇷
# 32             Eastern Africa  -6.000000   71.500000    🇮🇴
# 33         South-Eastern Asia   4.500000  114.666667    🇧🇳
# 34             Eastern Europe  43.000000   25.000000    🇧🇬
# 35             Western Africa  13.000000   -2.000000    🇧🇫
# 36             Eastern Africa  -3.500000   30.000000    🇧🇮
# 37         South-Eastern Asia  13.000000  105.000000    🇰🇭
# 38              Middle Africa   6.000000   12.000000    🇨🇲
# 39           Northern America  60.000000  -95.000000    🇨🇦
# 40             Western Africa  16.000000  -24.000000    🇨🇻
# 41                  Caribbean  19.500000  -80.500000    🇰🇾
# 42              Middle Africa   7.000000   21.000000    🇨🇫
# 43              Middle Africa  15.000000   19.000000    🇹🇩
# 44              South America -30.000000  -71.000000    🇨🇱
# 45               Eastern Asia  35.000000  105.000000    🇨🇳
# 46  Australia and New Zealand -10.500000  105.666667    🇨🇽
# 47  Australia and New Zealand -12.500000   96.833333    🇨🇨
# 48              South America   4.000000  -72.000000    🇨🇴
# 49             Eastern Africa -12.166667   44.250000    🇰🇲

# %%
df.to_csv('out.csv')

# %%
df = df.query('region == "Africa"')
df.head(50)
# Out:
#                                      name iso3 iso2 phone_code  \
# 3                                 Algeria  DZA   DZ        213
# 6                                  Angola  AGO   AO        244
# 23                                  Benin  BEN   BJ        229
# 29                               Botswana  BWA   BW        267
# 32         British Indian Ocean Territory  IOT   IO        246
# 35                           Burkina Faso  BFA   BF        226
# 36                                Burundi  BDI   BI        257
# 38                               Cameroon  CMR   CM        237
# 40                             Cape Verde  CPV   CV        238
# 42               Central African Republic  CAF   CF        236
# 43                                   Chad  TCD   TD        235
# 49                                Comoros  COM   KM        269
# 50                                  Congo  COG   CG        242
# 51   Congo The Democratic Republic Of The  COD   CD        243
# 54            Cote D'Ivoire (Ivory Coast)  CIV   CI        225
# 61                               Djibouti  DJI   DJ        253
# 66                                  Egypt  EGY   EG         20
# 68                      Equatorial Guinea  GNQ   GQ        240
# 69                                Eritrea  ERI   ER        291
# 71                               Ethiopia  ETH   ET        251
# 79            French Southern Territories  ATF   TF
# 80                                  Gabon  GAB   GA        241
# 81                             Gambia The  GMB   GM        220
# 84                                  Ghana  GHA   GH        233
# 93                                 Guinea  GIN   GN        224
# 94                          Guinea-Bissau  GNB   GW        245
# 114                                 Kenya  KEN   KE        254
# 124                               Lesotho  LSO   LS        266
# 125                               Liberia  LBR   LR        231
# 126                                 Libya  LBY   LY        218
# 132                            Madagascar  MDG   MG        261
# 133                                Malawi  MWI   MW        265
# 136                                  Mali  MLI   ML        223
# 141                            Mauritania  MRT   MR        222
# 142                             Mauritius  MUS   MU        230
# 143                               Mayotte  MYT   YT        262
# 151                               Morocco  MAR   MA        212
# 152                            Mozambique  MOZ   MZ        258
# 154                               Namibia  NAM   NA        264
# 161                                 Niger  NER   NE        227
# 162                               Nigeria  NGA   NG        234
# 181                               Reunion  REU   RE        262
# 184                                Rwanda  RWA   RW        250
# 185                          Saint Helena  SHN   SH        290
# 194                 Sao Tome and Principe  STP   ST        239
# 196                               Senegal  SEN   SN        221
# 198                            Seychelles  SYC   SC        248
# 199                          Sierra Leone  SLE   SL        232
# 205                               Somalia  SOM   SO        252
# 206                          South Africa  ZAF   ZA         27
#
#                capital currency currency_symbol  region        subregion  \
# 3              Algiers      DZD              دج  Africa  Northern Africa
# 6               Luanda      AOA              Kz  Africa    Middle Africa
# 23          Porto-Novo      XOF             CFA  Africa   Western Africa
# 29            Gaborone      BWP               P  Africa  Southern Africa
# 32        Diego Garcia      USD               $  Africa   Eastern Africa
# 35         Ouagadougou      XOF             CFA  Africa   Western Africa
# 36           Bujumbura      BIF             FBu  Africa   Eastern Africa
# 38             Yaounde      XAF            FCFA  Africa    Middle Africa
# 40               Praia      CVE               $  Africa   Western Africa
# 42              Bangui      XAF            FCFA  Africa    Middle Africa
# 43           N'Djamena      XAF            FCFA  Africa    Middle Africa
# 49              Moroni      KMF              CF  Africa   Eastern Africa
# 50         Brazzaville      XAF              FC  Africa    Middle Africa
# 51            Kinshasa      CDF              FC  Africa    Middle Africa
# 54        Yamoussoukro      XOF             CFA  Africa   Western Africa
# 61            Djibouti      DJF             Fdj  Africa   Eastern Africa
# 66               Cairo      EGP             ج.م  Africa  Northern Africa
# 68              Malabo      XAF            FCFA  Africa    Middle Africa
# 69              Asmara      ERN             Nfk  Africa   Eastern Africa
# 71         Addis Ababa      ETB             Nkf  Africa   Eastern Africa
# 79   Port-aux-Francais      EUR               €  Africa  Southern Africa
# 80          Libreville      XAF            FCFA  Africa    Middle Africa
# 81              Banjul      GMD               D  Africa   Western Africa
# 84               Accra      GHS             GH₵  Africa   Western Africa
# 93             Conakry      GNF              FG  Africa   Western Africa
# 94              Bissau      XOF             CFA  Africa   Western Africa
# 114            Nairobi      KES             KSh  Africa   Eastern Africa
# 124             Maseru      LSL               L  Africa  Southern Africa
# 125           Monrovia      LRD               $  Africa   Western Africa
# 126           Tripolis      LYD             د.ل  Africa  Northern Africa
# 132       Antananarivo      MGA              Ar  Africa   Eastern Africa
# 133           Lilongwe      MWK              MK  Africa   Eastern Africa
# 136             Bamako      XOF             CFA  Africa   Western Africa
# 141         Nouakchott      MRO             MRU  Africa   Western Africa
# 142         Port Louis      MUR               ₨  Africa   Eastern Africa
# 143          Mamoudzou      EUR               €  Africa   Eastern Africa
# 151              Rabat      MAD              DH  Africa  Northern Africa
# 152             Maputo      MZN              MT  Africa   Eastern Africa
# 154           Windhoek      NAD               $  Africa  Southern Africa
# 161             Niamey      XOF             CFA  Africa   Western Africa
# 162              Abuja      NGN               ₦  Africa   Western Africa
# 181        Saint-Denis      EUR               €  Africa   Eastern Africa
# 184             Kigali      RWF             FRw  Africa   Eastern Africa
# 185          Jamestown      SHP               £  Africa   Western Africa
# 194           Sao Tome      STD              Db  Africa    Middle Africa
# 196              Dakar      XOF             CFA  Africa   Western Africa
# 198           Victoria      SCR             SRe  Africa   Eastern Africa
# 199           Freetown      SLL              Le  Africa   Western Africa
# 205          Mogadishu      SOS          Sh.so.  Africa   Eastern Africa
# 206           Pretoria      ZAR               R  Africa  Southern Africa
#
#       latitude  longitude emoji
# 3    28.000000   3.000000    🇩🇿
# 6   -12.500000  18.500000    🇦🇴
# 23    9.500000   2.250000    🇧🇯
# 29  -22.000000  24.000000    🇧🇼
# 32   -6.000000  71.500000    🇮🇴
# 35   13.000000  -2.000000    🇧🇫
# 36   -3.500000  30.000000    🇧🇮
# 38    6.000000  12.000000    🇨🇲
# 40   16.000000 -24.000000    🇨🇻
# 42    7.000000  21.000000    🇨🇫
# 43   15.000000  19.000000    🇹🇩
# 49  -12.166667  44.250000    🇰🇲
# 50   -1.000000  15.000000    🇨🇬
# 51    0.000000  25.000000    🇨🇩
# 54    8.000000  -5.000000    🇨🇮
# 61   11.500000  43.000000    🇩🇯
# 66   27.000000  30.000000    🇪🇬
# 68    2.000000  10.000000    🇬🇶
# 69   15.000000  39.000000    🇪🇷
# 71    8.000000  38.000000    🇪🇹
# 79  -49.250000  69.167000    🇹🇫
# 80   -1.000000  11.750000    🇬🇦
# 81   13.466667 -16.566667    🇬🇲
# 84    8.000000  -2.000000    🇬🇭
# 93   11.000000 -10.000000    🇬🇳
# 94   12.000000 -15.000000    🇬🇼
# 114   1.000000  38.000000    🇰🇪
# 124 -29.500000  28.500000    🇱🇸
# 125   6.500000  -9.500000    🇱🇷
# 126  25.000000  17.000000    🇱🇾
# 132 -20.000000  47.000000    🇲🇬
# 133 -13.500000  34.000000    🇲🇼
# 136  17.000000  -4.000000    🇲🇱
# 141  20.000000 -12.000000    🇲🇷
# 142 -20.283333  57.550000    🇲🇺
# 143 -12.833333  45.166667    🇾🇹
# 151  32.000000  -5.000000    🇲🇦
# 152 -18.250000  35.000000    🇲🇿
# 154 -22.000000  17.000000    🇳🇦
# 161  16.000000   8.000000    🇳🇪
# 162  10.000000   8.000000    🇳🇬
# 181 -21.150000  55.500000    🇷🇪
# 184  -2.000000  30.000000    🇷🇼
# 185 -15.950000  -5.700000    🇸🇭
# 194   1.000000   7.000000    🇸🇹
# 196  14.000000 -14.000000    🇸🇳
# 198  -4.583333  55.666667    🇸🇨
# 199   8.500000 -11.500000    🇸🇱
# 205  10.000000  49.000000    🇸🇴
# 206 -29.000000  24.000000    🇿🇦

# %%
def africa():
    df = pd.read_json('c.json')
    df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id'], axis = 1)
    data = df.query('region == "Africa"')
    # df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
    return data
africa().head()
# Out:
#                               name iso3 iso2 phone_code       capital  \
# 3                          Algeria  DZA   DZ        213       Algiers
# 6                           Angola  AGO   AO        244        Luanda
# 23                           Benin  BEN   BJ        229    Porto-Novo
# 29                        Botswana  BWA   BW        267      Gaborone
# 32  British Indian Ocean Territory  IOT   IO        246  Diego Garcia
#
#    currency currency_symbol  region        subregion  latitude  longitude  \
# 3       DZD              دج  Africa  Northern Africa      28.0       3.00
# 6       AOA              Kz  Africa    Middle Africa     -12.5      18.50
# 23      XOF             CFA  Africa   Western Africa       9.5       2.25
# 29      BWP               P  Africa  Southern Africa     -22.0      24.00
# 32      USD               $  Africa   Eastern Africa      -6.0      71.50
#
#    emoji
# 3     🇩🇿
# 6     🇦🇴
# 23    🇧🇯
# 29    🇧🇼
# 32    🇮🇴

# %%
def asia():
    df = pd.read_json('c.json')
    df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id'], axis = 1)
    data = df.query('region == "Asia"')
    # df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
    return data
asia()
# Out:
#                                name iso3 iso2 phone_code              capital  \
# 0                       Afghanistan  AFG   AF         93                Kabul
# 11                          Armenia  ARM   AM        374              Yerevan
# 15                       Azerbaijan  AZE   AZ        994                 Baku
# 17                          Bahrain  BHR   BH        973               Manama
# 18                       Bangladesh  BGD   BD        880                Dhaka
# 25                           Bhutan  BTN   BT        975              Thimphu
# 33                           Brunei  BRN   BN        673  Bandar Seri Begawan
# 37                         Cambodia  KHM   KH        855           Phnom Penh
# 45                            China  CHN   CN         86              Beijing
# 64                       East Timor  TLS   TL        670                 Dili
# 82                          Georgia  GEO   GE        995              Tbilisi
# 99                 Hong Kong S.A.R.  HKG   HK        852            Hong Kong
# 102                           India  IND   IN         91            New Delhi
# 103                       Indonesia  IDN   ID         62              Jakarta
# 104                            Iran  IRN   IR         98               Tehran
# 105                            Iraq  IRQ   IQ        964              Baghdad
# 107                          Israel  ISR   IL        972            Jerusalem
# 110                           Japan  JPN   JP         81                Tokyo
# 112                          Jordan  JOR   JO        962                Amman
# 113                      Kazakhstan  KAZ   KZ          7               Astana
# 116                     Korea North  PRK   KP        850            Pyongyang
# 117                     Korea South  KOR   KR         82                Seoul
# 119                          Kuwait  KWT   KW        965          Kuwait City
# 120                      Kyrgyzstan  KGZ   KG        996              Bishkek
# 121                            Laos  LAO   LA        856            Vientiane
# 123                         Lebanon  LBN   LB        961               Beirut
# 130                    Macau S.A.R.  MAC   MO        853                Macao
# 134                        Malaysia  MYS   MY         60         Kuala Lumpur
# 135                        Maldives  MDV   MV        960                 Male
# 148                        Mongolia  MNG   MN        976           Ulan Bator
# 153                         Myanmar  MMR   MM         95          Nay Pyi Taw
# 156                           Nepal  NPL   NP        977            Kathmandu
# 167                            Oman  OMN   OM        968               Muscat
# 168                        Pakistan  PAK   PK         92            Islamabad
# 170  Palestinian Territory Occupied  PSE   PS        970       East Jerusalem
# 175                     Philippines  PHL   PH         63               Manila
# 180                           Qatar  QAT   QA        974                 Doha
# 195                    Saudi Arabia  SAU   SA        966               Riyadh
# 200                       Singapore  SGP   SG         65             Singapur
# 210                       Sri Lanka  LKA   LK         94              Colombo
# 217                           Syria  SYR   SY        963             Damascus
# 218                          Taiwan  TWN   TW        886               Taipei
# 219                      Tajikistan  TJK   TJ        992             Dushanbe
# 221                        Thailand  THA   TH         66              Bangkok
# 227                          Turkey  TUR   TR         90               Ankara
# 228                    Turkmenistan  TKM   TM        993             Ashgabat
# 233            United Arab Emirates  ARE   AE        971            Abu Dhabi
# 238                      Uzbekistan  UZB   UZ        998             Tashkent
# 242                         Vietnam  VNM   VN         84                Hanoi
# 247                           Yemen  YEM   YE        967                Sanaa
#
#     currency currency_symbol region           subregion   latitude  \
# 0        AFN               ؋   Asia       Southern Asia  33.000000
# 11       AMD               ֏   Asia        Western Asia  40.000000
# 15       AZN               m   Asia        Western Asia  40.500000
# 17       BHD            .د.ب   Asia        Western Asia  26.000000
# 18       BDT               ৳   Asia       Southern Asia  24.000000
# 25       BTN             Nu.   Asia       Southern Asia  27.500000
# 33       BND              B$   Asia  South-Eastern Asia   4.500000
# 37       KHR             KHR   Asia  South-Eastern Asia  13.000000
# 45       CNY               ¥   Asia        Eastern Asia  35.000000
# 64       USD               $   Asia  South-Eastern Asia  -8.833333
# 82       GEL               ლ   Asia        Western Asia  42.000000
# 99       HKD               $   Asia        Eastern Asia  22.250000
# 102      INR               ₹   Asia       Southern Asia  20.000000
# 103      IDR              Rp   Asia  South-Eastern Asia  -5.000000
# 104      IRR               ﷼   Asia       Southern Asia  32.000000
# 105      IQD             د.ع   Asia        Western Asia  33.000000
# 107      ILS               ₪   Asia        Western Asia  31.500000
# 110      JPY               ¥   Asia        Eastern Asia  36.000000
# 112      JOD             ا.د   Asia        Western Asia  31.000000
# 113      KZT              лв   Asia        Central Asia  48.000000
# 116      KPW               ₩   Asia        Eastern Asia  40.000000
# 117      KRW               ₩   Asia        Eastern Asia  37.000000
# 119      KWD             ك.د   Asia        Western Asia  29.500000
# 120      KGS              лв   Asia        Central Asia  41.000000
# 121      LAK               ₭   Asia  South-Eastern Asia  18.000000
# 123      LBP               £   Asia        Western Asia  33.833333
# 130      MOP               $   Asia        Eastern Asia  22.166667
# 134      MYR              RM   Asia  South-Eastern Asia   2.500000
# 135      MVR              Rf   Asia       Southern Asia   3.250000
# 148      MNT               ₮   Asia        Eastern Asia  46.000000
# 153      MMK               K   Asia  South-Eastern Asia  22.000000
# 156      NPR               ₨   Asia       Southern Asia  28.000000
# 167      OMR            .ع.ر   Asia        Western Asia  21.000000
# 168      PKR               ₨   Asia       Southern Asia  30.000000
# 170      ILS               ₪   Asia        Western Asia  31.900000
# 175      PHP               ₱   Asia  South-Eastern Asia  13.000000
# 180      QAR             ق.ر   Asia        Western Asia  25.500000
# 195      SAR               ﷼   Asia        Western Asia  25.000000
# 200      SGD               $   Asia  South-Eastern Asia   1.366667
# 210      LKR              Rs   Asia       Southern Asia   7.000000
# 217      SYP              LS   Asia        Western Asia  35.000000
# 218      TWD               $   Asia        Eastern Asia  23.500000
# 219      TJS              SM   Asia        Central Asia  39.000000
# 221      THB               ฿   Asia  South-Eastern Asia  15.000000
# 227      TRY               ₺   Asia        Western Asia  39.000000
# 228      TMT               T   Asia        Central Asia  40.000000
# 233      AED             إ.د   Asia        Western Asia  24.000000
# 238      UZS              лв   Asia        Central Asia  41.000000
# 242      VND               ₫   Asia  South-Eastern Asia  16.166667
# 247      YER               ﷼   Asia        Western Asia  15.000000
#
#       longitude emoji
# 0     65.000000    🇦🇫
# 11    45.000000    🇦🇲
# 15    47.500000    🇦🇿
# 17    50.550000    🇧🇭
# 18    90.000000    🇧🇩
# 25    90.500000    🇧🇹
# 33   114.666667    🇧🇳
# 37   105.000000    🇰🇭
# 45   105.000000    🇨🇳
# 64   125.916667    🇹🇱
# 82    43.500000    🇬🇪
# 99   114.166667    🇭🇰
# 102   77.000000    🇮🇳
# 103  120.000000    🇮🇩
# 104   53.000000    🇮🇷
# 105   44.000000    🇮🇶
# 107   34.750000    🇮🇱
# 110  138.000000    🇯🇵
# 112   36.000000    🇯🇴
# 113   68.000000    🇰🇿
# 116  127.000000    🇰🇵
# 117  127.500000    🇰🇷
# 119   45.750000    🇰🇼
# 120   75.000000    🇰🇬
# 121  105.000000    🇱🇦
# 123   35.833333    🇱🇧
# 130  113.550000    🇲🇴
# 134  112.500000    🇲🇾
# 135   73.000000    🇲🇻
# 148  105.000000    🇲🇳
# 153   98.000000    🇲🇲
# 156   84.000000    🇳🇵
# 167   57.000000    🇴🇲
# 168   70.000000    🇵🇰
# 170   35.200000    🇵🇸
# 175  122.000000    🇵🇭
# 180   51.250000    🇶🇦
# 195   45.000000    🇸🇦
# 200  103.800000    🇸🇬
# 210   81.000000    🇱🇰
# 217   38.000000    🇸🇾
# 218  121.000000    🇹🇼
# 219   71.000000    🇹🇯
# 221  100.000000    🇹🇭
# 227   35.000000    🇹🇷
# 228   60.000000    🇹🇲
# 233   54.000000    🇦🇪
# 238   64.000000    🇺🇿
# 242  107.833333    🇻🇳
# 247   48.000000    🇾🇪

# %%
def oceania():
    df = pd.read_json('c.json')
    df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id'], axis = 1)
    df = df.query('region == "Oceania"')
    # df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
    return df
oceania()
# Out:
#                           name iso3 iso2 phone_code           capital  \
# 4               American Samoa  ASM   AS     +1-684         Pago Pago
# 13                   Australia  AUS   AU         61          Canberra
# 46            Christmas Island  CXR   CX         61  Flying Fish Cove
# 47     Cocos (Keeling) Islands  CCK   CC         61       West Island
# 52                Cook Islands  COK   CK        682            Avarua
# 74                Fiji Islands  FJI   FJ        679              Suva
# 78            French Polynesia  PYF   PF        689           Papeete
# 90                        Guam  GUM   GU     +1-671           Hagatna
# 115                   Kiribati  KIR   KI        686            Tarawa
# 139           Marshall Islands  MHL   MH        692            Majuro
# 145                 Micronesia  FSM   FM        691           Palikir
# 155                      Nauru  NRU   NR        674             Yaren
# 158              New Caledonia  NCL   NC        687            Noumea
# 159                New Zealand  NZL   NZ         64        Wellington
# 163                       Niue  NIU   NU        683             Alofi
# 164             Norfolk Island  NFK   NF        672          Kingston
# 165   Northern Mariana Islands  MNP   MP     +1-670            Saipan
# 169                      Palau  PLW   PW        680          Melekeok
# 172           Papua new Guinea  PNG   PG        675      Port Moresby
# 176            Pitcairn Island  PCN   PN        870         Adamstown
# 192                      Samoa  WSM   WS        685              Apia
# 204            Solomon Islands  SLB   SB        677           Honiara
# 223                    Tokelau  TKL   TK        690
# 224                      Tonga  TON   TO        676        Nuku'alofa
# 230                     Tuvalu  TUV   TV        688          Funafuti
# 239                    Vanuatu  VUT   VU        678         Port Vila
# 245  Wallis And Futuna Islands  WLF   WF        681          Mata Utu
#
#     currency currency_symbol   region                  subregion   latitude  \
# 4        USD               $  Oceania                  Polynesia -14.333333
# 13       AUD               $  Oceania  Australia and New Zealand -27.000000
# 46       AUD               $  Oceania  Australia and New Zealand -10.500000
# 47       AUD               $  Oceania  Australia and New Zealand -12.500000
# 52       NZD               $  Oceania                  Polynesia -21.233333
# 74       FJD             FJ$  Oceania                  Melanesia -18.000000
# 78       XPF               ₣  Oceania                  Polynesia -15.000000
# 90       USD               $  Oceania                 Micronesia  13.466667
# 115      AUD               $  Oceania                 Micronesia   1.416667
# 139      USD               $  Oceania                 Micronesia   9.000000
# 145      USD               $  Oceania                 Micronesia   6.916667
# 155      AUD               $  Oceania                 Micronesia  -0.533333
# 158      XPF               ₣  Oceania                  Melanesia -21.500000
# 159      NZD               $  Oceania  Australia and New Zealand -41.000000
# 163      NZD               $  Oceania                  Polynesia -19.033333
# 164      AUD               $  Oceania  Australia and New Zealand -29.033333
# 165      USD               $  Oceania                 Micronesia  15.200000
# 169      USD               $  Oceania                 Micronesia   7.500000
# 172      PGK               K  Oceania                  Melanesia  -6.000000
# 176      NZD               $  Oceania                  Polynesia -25.066667
# 192      WST             SAT  Oceania                  Polynesia -13.583333
# 204      SBD             Si$  Oceania                  Melanesia  -8.000000
# 223      NZD               $  Oceania                  Polynesia  -9.000000
# 224      TOP               $  Oceania                  Polynesia -20.000000
# 230      AUD               $  Oceania                  Polynesia  -8.000000
# 239      VUV              VT  Oceania                  Melanesia -16.000000
# 245      XPF               ₣  Oceania                  Polynesia -13.300000
#
#       longitude emoji
# 4   -170.000000    🇦🇸
# 13   133.000000    🇦🇺
# 46   105.666667    🇨🇽
# 47    96.833333    🇨🇨
# 52  -159.766667    🇨🇰
# 74   175.000000    🇫🇯
# 78  -140.000000    🇵🇫
# 90   144.783333    🇬🇺
# 115  173.000000    🇰🇮
# 139  168.000000    🇲🇭
# 145  158.250000    🇫🇲
# 155  166.916667    🇳🇷
# 158  165.500000    🇳🇨
# 159  174.000000    🇳🇿
# 163 -169.866667    🇳🇺
# 164  167.950000    🇳🇫
# 165  145.750000    🇲🇵
# 169  134.500000    🇵🇼
# 172  147.000000    🇵🇬
# 176 -130.100000    🇵🇳
# 192 -172.333333    🇼🇸
# 204  159.000000    🇸🇧
# 223 -172.000000    🇹🇰
# 224 -175.000000    🇹🇴
# 230  178.000000    🇹🇻
# 239  167.000000    🇻🇺
# 245 -176.200000    🇼🇫

# %%
def europe():
    df = pd.read_json('c.json')
    df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id'], axis = 1)
    df = df.query('region == "Europe"')
    # df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
    return df
europe()
# Out:
#                                name iso3 iso2 phone_code  \
# 1                     Aland Islands  ALA   AX    +358-18
# 2                           Albania  ALB   AL        355
# 5                           Andorra  AND   AD        376
# 14                          Austria  AUT   AT         43
# 20                          Belarus  BLR   BY        375
# 21                          Belgium  BEL   BE         32
# 28           Bosnia and Herzegovina  BIH   BA        387
# 34                         Bulgaria  BGR   BG        359
# 55               Croatia (Hrvatska)  HRV   HR        385
# 58                           Cyprus  CYP   CY        357
# 59                   Czech Republic  CZE   CZ        420
# 60                          Denmark  DNK   DK         45
# 70                          Estonia  EST   EE        372
# 73                    Faroe Islands  FRO   FO        298
# 75                          Finland  FIN   FI        358
# 76                           France  FRA   FR         33
# 83                          Germany  DEU   DE         49
# 85                        Gibraltar  GIB   GI        350
# 86                           Greece  GRC   GR         30
# 92            Guernsey and Alderney  GGY   GG   +44-1481
# 100                         Hungary  HUN   HU         36
# 101                         Iceland  ISL   IS        354
# 106                         Ireland  IRL   IE        353
# 108                           Italy  ITA   IT         39
# 111                          Jersey  JEY   JE   +44-1534
# 118                          Kosovo  XKX   XK        383
# 122                          Latvia  LVA   LV        371
# 127                   Liechtenstein  LIE   LI        423
# 128                       Lithuania  LTU   LT        370
# 129                      Luxembourg  LUX   LU        352
# 131                       Macedonia  MKD   MK        389
# 137                           Malta  MLT   MT        356
# 138                   Man (Isle of)  IMN   IM   +44-1624
# 146                         Moldova  MDA   MD        373
# 147                          Monaco  MCO   MC        377
# 149                      Montenegro  MNE   ME        382
# 157                 Netherlands The  NLD   NL         31
# 166                          Norway  NOR   NO         47
# 177                          Poland  POL   PL         48
# 178                        Portugal  PRT   PT        351
# 182                         Romania  ROU   RO         40
# 183                          Russia  RUS   RU          7
# 193                      San Marino  SMR   SM        378
# 197                          Serbia  SRB   RS        381
# 202                        Slovakia  SVK   SK        421
# 203                        Slovenia  SVN   SI        386
# 209                           Spain  ESP   ES         34
# 213  Svalbard And Jan Mayen Islands  SJM   SJ         47
# 215                          Sweden  SWE   SE         46
# 216                     Switzerland  CHE   CH         41
# 232                         Ukraine  UKR   UA        380
# 234                  United Kingdom  GBR   GB         44
# 240   Vatican City State (Holy See)  VAT   VA        379
#
#                   capital currency currency_symbol  region        subregion  \
# 1               Mariehamn      EUR               €  Europe  Northern Europe
# 2                  Tirana      ALL             Lek  Europe  Southern Europe
# 5        Andorra la Vella      EUR               €  Europe  Southern Europe
# 14                 Vienna      EUR               €  Europe   Western Europe
# 20                  Minsk      BYN              Br  Europe   Eastern Europe
# 21               Brussels      EUR               €  Europe   Western Europe
# 28               Sarajevo      BAM              KM  Europe  Southern Europe
# 34                  Sofia      BGN             Лв.  Europe   Eastern Europe
# 55                 Zagreb      HRK              kn  Europe  Southern Europe
# 58                Nicosia      EUR               €  Europe  Southern Europe
# 59                 Prague      CZK              Kč  Europe   Eastern Europe
# 60             Copenhagen      DKK             Kr.  Europe  Northern Europe
# 70                Tallinn      EUR               €  Europe  Northern Europe
# 73               Torshavn      DKK             Kr.  Europe  Northern Europe
# 75               Helsinki      EUR               €  Europe  Northern Europe
# 76                  Paris      EUR               €  Europe   Western Europe
# 83                 Berlin      EUR               €  Europe   Western Europe
# 85              Gibraltar      GIP               £  Europe  Southern Europe
# 86                 Athens      EUR               €  Europe  Southern Europe
# 92          St Peter Port      GBP               £  Europe  Northern Europe
# 100              Budapest      HUF              Ft  Europe   Eastern Europe
# 101             Reykjavik      ISK              kr  Europe  Northern Europe
# 106                Dublin      EUR               €  Europe  Northern Europe
# 108                  Rome      EUR               €  Europe  Southern Europe
# 111          Saint Helier      GBP               £  Europe  Northern Europe
# 118              Pristina      EUR               €  Europe   Eastern Europe
# 122                  Riga      EUR               €  Europe  Northern Europe
# 127                 Vaduz      CHF             CHf  Europe   Western Europe
# 128               Vilnius      EUR               €  Europe  Northern Europe
# 129            Luxembourg      EUR               €  Europe   Western Europe
# 131                Skopje      MKD             ден  Europe  Southern Europe
# 137              Valletta      EUR               €  Europe  Southern Europe
# 138  Douglas, Isle of Man      GBP               £  Europe  Northern Europe
# 146              Chisinau      MDL               L  Europe   Eastern Europe
# 147                Monaco      EUR               €  Europe   Western Europe
# 149             Podgorica      EUR               €  Europe  Southern Europe
# 157             Amsterdam      EUR               €  Europe   Western Europe
# 166                  Oslo      NOK              kr  Europe  Northern Europe
# 177                Warsaw      PLN              zł  Europe   Eastern Europe
# 178                Lisbon      EUR               €  Europe  Southern Europe
# 182             Bucharest      RON             lei  Europe   Eastern Europe
# 183                Moscow      RUB               ₽  Europe   Eastern Europe
# 193            San Marino      EUR               €  Europe  Southern Europe
# 197              Belgrade      RSD             din  Europe  Southern Europe
# 202            Bratislava      EUR               €  Europe   Eastern Europe
# 203             Ljubljana      EUR               €  Europe  Southern Europe
# 209                Madrid      EUR               €  Europe  Southern Europe
# 213          Longyearbyen      NOK              kr  Europe  Northern Europe
# 215             Stockholm      SEK              kr  Europe  Northern Europe
# 216                 Berne      CHF             CHf  Europe   Western Europe
# 232                  Kiev      UAH               ₴  Europe   Eastern Europe
# 234                London      GBP               £  Europe  Northern Europe
# 240          Vatican City      EUR               €  Europe  Southern Europe
#
#       latitude   longitude emoji
# 1    60.116667   19.900000    🇦🇽
# 2    41.000000   20.000000    🇦🇱
# 5    42.500000    1.500000    🇦🇩
# 14   47.333333   13.333333    🇦🇹
# 20   53.000000   28.000000    🇧🇾
# 21   50.833333    4.000000    🇧🇪
# 28   44.000000   18.000000    🇧🇦
# 34   43.000000   25.000000    🇧🇬
# 55   45.166667   15.500000    🇭🇷
# 58   35.000000   33.000000    🇨🇾
# 59   49.750000   15.500000    🇨🇿
# 60   56.000000   10.000000    🇩🇰
# 70   59.000000   26.000000    🇪🇪
# 73   62.000000   -7.000000    🇫🇴
# 75   64.000000   26.000000    🇫🇮
# 76   46.000000    2.000000    🇫🇷
# 83   51.000000    9.000000    🇩🇪
# 85   36.133333   -5.350000    🇬🇮
# 86   39.000000   22.000000    🇬🇷
# 92   49.466667   -2.583333    🇬🇬
# 100  47.000000   20.000000    🇭🇺
# 101  65.000000  -18.000000    🇮🇸
# 106  53.000000   -8.000000    🇮🇪
# 108  42.833333   12.833333    🇮🇹
# 111  49.250000   -2.166667    🇯🇪
# 118  42.561291   20.340304    🇽🇰
# 122  57.000000   25.000000    🇱🇻
# 127  47.266667    9.533333    🇱🇮
# 128  56.000000   24.000000    🇱🇹
# 129  49.750000    6.166667    🇱🇺
# 131  41.833333   22.000000    🇲🇰
# 137  35.833333   14.583333    🇲🇹
# 138  54.250000   -4.500000    🇮🇲
# 146  47.000000   29.000000    🇲🇩
# 147  43.733333    7.400000    🇲🇨
# 149  42.500000   19.300000    🇲🇪
# 157  52.500000    5.750000    🇳🇱
# 166  62.000000   10.000000    🇳🇴
# 177  52.000000   20.000000    🇵🇱
# 178  39.500000   -8.000000    🇵🇹
# 182  46.000000   25.000000    🇷🇴
# 183  60.000000  100.000000    🇷🇺
# 193  43.766667   12.416667    🇸🇲
# 197  44.000000   21.000000    🇷🇸
# 202  48.666667   19.500000    🇸🇰
# 203  46.116667   14.816667    🇸🇮
# 209  40.000000   -4.000000    🇪🇸
# 213  78.000000   20.000000    🇸🇯
# 215  62.000000   15.000000    🇸🇪
# 216  47.000000    8.000000    🇨🇭
# 232  49.000000   32.000000    🇺🇦
# 234  54.000000   -2.000000    🇬🇧
# 240  41.900000   12.450000    🇻🇦

# %%
def americas():
    df = pd.read_json('c.json')
    df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id'], axis = 1)
    df = df.query('region == "Americas"')
    # df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
    return df
americas().head()
# Out:
#                    name iso3 iso2 phone_code       capital currency  \
# 7              Anguilla  AIA   AI     +1-264    The Valley      XCD
# 9   Antigua And Barbuda  ATG   AG     +1-268    St. John's      XCD
# 10            Argentina  ARG   AR         54  Buenos Aires      ARS
# 12                Aruba  ABW   AW        297    Oranjestad      AWG
# 16          Bahamas The  BHS   BS     +1-242        Nassau      BSD
#
#    currency_symbol    region      subregion  latitude  longitude emoji
# 7                $  Americas      Caribbean     18.25 -63.166667    🇦🇮
# 9                $  Americas      Caribbean     17.05 -61.800000    🇦🇬
# 10               $  Americas  South America    -34.00 -64.000000    🇦🇷
# 12               ƒ  Americas      Caribbean     12.50 -69.966667    🇦🇼
# 16              B$  Americas      Caribbean     24.25 -76.000000    🇧🇸

# %%
def polar():
    df = pd.read_json('c.json')
    df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id'], axis = 1)
    df = df.query('region == "Polar"')
    # df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
    return df
polar()
# Out:
#          name iso3 iso2 phone_code capital currency currency_symbol region  \
# 8  Antarctica  ATA   AQ                                           $  Polar
#
#   subregion  latitude  longitude emoji
# 8              -74.65       4.48    🇦🇶

# %% [markdown]
# ### Sub-regions

# %%
def americas():
    df = pd.read_json('c.json')
    df = df.query('region == "Americas"')
    df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
    return df
americas().head()
# Out:
#                    name       capital  latitude  longitude emoji
# 7              Anguilla    The Valley     18.25 -63.166667    🇦🇮
# 9   Antigua And Barbuda    St. John's     17.05 -61.800000    🇦🇬
# 10            Argentina  Buenos Aires    -34.00 -64.000000    🇦🇷
# 12                Aruba    Oranjestad     12.50 -69.966667    🇦🇼
# 16          Bahamas The        Nassau     24.25 -76.000000    🇧🇸

# %%
def south_asia():
    df = pd.read_json('c.json')
    df = df.query('subregion == "Southern Asia"')
    df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
    return df
south_asia()
# Out:
#             name    capital  latitude  longitude emoji
# 0    Afghanistan      Kabul     33.00       65.0    🇦🇫
# 18    Bangladesh      Dhaka     24.00       90.0    🇧🇩
# 25        Bhutan    Thimphu     27.50       90.5    🇧🇹
# 102        India  New Delhi     20.00       77.0    🇮🇳
# 104         Iran     Tehran     32.00       53.0    🇮🇷
# 135     Maldives       Male      3.25       73.0    🇲🇻
# 156        Nepal  Kathmandu     28.00       84.0    🇳🇵
# 168     Pakistan  Islamabad     30.00       70.0    🇵🇰
# 210    Sri Lanka    Colombo      7.00       81.0    🇱🇰

# %%
def northern_europe():
    df = df.query('subregion == "Northern Europe"')
    df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
    return df
northern_europe().head()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-14-e0d9de059936> in <module>
#       3     df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
#       4     return df
# ----> 5 northern_europe().head()
#
# <ipython-input-14-e0d9de059936> in northern_europe()
#       1 def northern_europe():
# ----> 2     df = df.query('subregion == "Northern Europe"')
#       3     df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
#       4     return df
#       5 northern_europe().head()
#
# UnboundLocalError: local variable 'df' referenced before assignment

# %%
def northern_africa():
    df = full_df.query('subregion == "Northern Africa"')
    df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
    return df
northern_africa().head()
# Out:
# Empty DataFrame
# Columns: [name, capital, latitude, longitude, emoji]
# Index: []

# %%
def south_europe():
    df = full_df.query('subregion == "Southern Europe"')
    df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
    return df
south_europe().head()
# Out:
# Empty DataFrame
# Columns: [name, capital, latitude, longitude, emoji]
# Index: []

# %%
def polynesia():
    df = full_df.query('subregion == "Polynesia"')
    df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
    return df
polynesia().head()
# Out:
# Empty DataFrame
# Columns: [name, capital, latitude, longitude, emoji]
# Index: []

# %%
def middle_africa():
    df = full_df.query('subregion == "Middle Africa"')
    df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
    return df
middle_africa().head()
# Out:
# Empty DataFrame
# Columns: [name, capital, latitude, longitude, emoji]
# Index: []

# %%
def caribbean():
    df = full_df.query('subregion == "Caribbean"')
    df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
    return df
caribbean().head()
# Out:
# Empty DataFrame
# Columns: [name, capital, latitude, longitude, emoji]
# Index: []

# %%
def south_america():
    df = full_df.query('subregion == "South America"')
    df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
    return df
south_america().head()
# Out:
# Empty DataFrame
# Columns: [name, capital, latitude, longitude, emoji]
# Index: []

# %%
def western_asia():
    df = full_df.query('subregion == "Western Asia"')
    df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
    return df
western_asia().head()
# Out:
# Empty DataFrame
# Columns: [name, capital, latitude, longitude, emoji]
# Index: []

# %%
def western_europe():
    df = full_df.query('subregion == "Western Europe"')
    df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
    return df
western_europe().head()
# Out:
# Empty DataFrame
# Columns: [name, capital, latitude, longitude, emoji]
# Index: []

# %%
def central_america():
    df = full_df.query('subregion == "Central America"')
    df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
    return df
central_america().head()
# Out:
# Empty DataFrame
# Columns: [name, capital, latitude, longitude, emoji]
# Index: []

# %%
def western_africa():
    df = full_df.query('subregion == "Western Africa"')
    df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
    return df
western_africa().head()
# Out:
# Empty DataFrame
# Columns: [name, capital, latitude, longitude, emoji]
# Index: []

# %%
def northern_america():
    df = full_df.query('subregion == "Northern America"')
    df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
    return df
northern_america().head()
# Out:
# Empty DataFrame
# Columns: [name, capital, latitude, longitude, emoji]
# Index: []

# %%
def southern_africa():
    df = full_df.query('subregion == "Southern Africa"')
    df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
    return df
southern_africa().head()
# Out:
#              name   capital  latitude  longitude emoji
# 206  South Africa  Pretoria     -29.0       24.0    🇿🇦

# %%
def eastern_africa():
    df = full_df.query('subregion == "Eastern Africa"')
    df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
    return df
eastern_africa().head()
# Out:
# Empty DataFrame
# Columns: [name, capital, latitude, longitude, emoji]
# Index: []

# %%
def south_eastern_asia():
    df = full_df.query('subregion == "South-Eastern Asia"')
    df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
    return df
south_eastern_asia().head()
# Out:
# Empty DataFrame
# Columns: [name, capital, latitude, longitude, emoji]
# Index: []

# %%
def eastern_europe():
    df = full_df.query('subregion == "Eastern Europe"')
    df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
    return df
eastern_europe().head()
# Out:
# Empty DataFrame
# Columns: [name, capital, latitude, longitude, emoji]
# Index: []

# %%
def eastern_asia():
    df = full_df.query('subregion == "Eastern Asia"')
    df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
    return df
eastern_asia().head()
# Out:
# Empty DataFrame
# Columns: [name, capital, latitude, longitude, emoji]
# Index: []

# %%
def australia_newzealand():
    df = full_df.query('subregion == "Australia and New Zealand"')
    df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
    return df
australia_newzealand().head()
# Out:
# Empty DataFrame
# Columns: [name, capital, latitude, longitude, emoji]
# Index: []

# %%
def melanesia():
    df = full_df.query('subregion == "Melanesia"')
    df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
    return df
melanesia().head()
# Out:
# Empty DataFrame
# Columns: [name, capital, latitude, longitude, emoji]
# Index: []

# %%
def central_asia():
    df = full_df.query('subregion == "Central Asia"')
    df = df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
    return df
central_asia().head()
# Out:
# Empty DataFrame
# Columns: [name, capital, latitude, longitude, emoji]
# Index: []

# %%
def countries():
    df = full_df.drop(['timezones', 'translations', 'states', 'emojiU', 'native', 'tld', 'id', 'iso3', 'iso2', 'currency_symbol', 'currency', 'phone_code', 'subregion', 'region',], axis = 1)
    return df
countries().head()
# Out:
#              name   capital  latitude  longitude emoji
# 206  South Africa  Pretoria     -29.0       24.0    🇿🇦
