# %%
import numpy as np
import pandas as pd

# %%
df  = pd.read_csv("land.csv")

# %%
df
# Out:
#            country country_code  year  total_population  agric_irrigated_land  \
# 0      Afghanistan          AFG  1960      8.996967e+06                   NaN
# 1      Afghanistan          AFG  1961      9.169406e+06                   NaN
# 2      Afghanistan          AFG  1962      9.351442e+06                   NaN
# 3      Afghanistan          AFG  1963      9.543200e+06                   NaN
# 4      Afghanistan          AFG  1964      9.744772e+06                   NaN
# ...            ...          ...   ...               ...                   ...
# 16221        World          WLD  2016      7.424485e+09                   NaN
# 16222        World          WLD  2017      7.509410e+09                   NaN
# 16223        World          WLD  2018      7.592476e+09                   NaN
# 16224        World          WLD  2019      7.673345e+09                   NaN
# 16225        World          WLD  2020      7.752841e+09                   NaN
#
# ...

# %%
def total_population():
    data = pd.read_csv("land.csv")
    data = data[["year", "total_population"]]
    return data

# %%
total_population()
# Out:
#        year  total_population
# 0      1960      8.996967e+06
# 1      1961      9.169406e+06
# 2      1962      9.351442e+06
# 3      1963      9.543200e+06
# 4      1964      9.744772e+06
# ...     ...               ...
# 16221  2016      7.424485e+09
# 16222  2017      7.509410e+09
# 16223  2018      7.592476e+09
# 16224  2019      7.673345e+09
# 16225  2020      7.752841e+09
#
# [16226 rows x 2 columns]
