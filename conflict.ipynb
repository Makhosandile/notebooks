# %%
import numpy as np
import pandas as pd

# %%
deficit_df = pd.read_csv("conflict_fragility.csv")

# %%
def battle_related_deaths():
    """Battle-related deaths (number of people) [VC.BTL.DETH]"""
    df = deficit_df[["year", "country", "battle_related_deaths"]]
    return df

# %%
battle_related_deaths()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        battle_related_deaths
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...

# %%
def intentional_homicides():
    """Intentional homicides (per 100,000 people) [VC.IHR.PSRC.P5]"""
    df = deficit_df[["year", "country", "intentional_homicides"]]
    return df

# %%
intentional_homicides()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        intentional_homicides
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...

# %%
def intentional_homicides_female():
    """intentional_homicides_female (per 100,000 female)"""
    df = deficit_df[["year", "country", "intentional_homicides_female"]]
    return df

# %%
intentional_homicides_female()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        intentional_homicides_female
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# ...

# %%
def intentional_homicides_male():
    """intentional_homicides_male (per 100,000 male)"""
    df = deficit_df[["year", "country", "intentional_homicides_male"]]
    return df

# %%
intentional_homicides_male()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        intentional_homicides_male
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# ...

# %%
def internally_displaced_persons():
    """internally_displaced_persons, new displacement associated with conflict and violence (number of cases)"""
    df = deficit_df[["year", "country", "internally_displaced_persons"]]
    return df

# %%
internally_displaced_persons()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        internally_displaced_persons
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# ...

# %%
def internally_displaced_persons_disasters():
    """internally_displaced_persons, new displacement associated with disasters (number of cases)"""
    df = deficit_df[["year", "country", "internally_displaced_persons_disasters"]]
    return df

# %%
internally_displaced_persons_disasters()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        internally_displaced_persons_disasters
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# ...

# %%
def internally_displaced_persons_total_displaced_by_conflict():
    """internally_displaced_persons_total_displaced_by_conflict"""
    df = deficit_df[["year", "country", "internally_displaced_persons_total_displaced_by_conflict"]]
    return df

# %%
internally_displaced_persons_total_displaced_by_conflict()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        internally_displaced_persons_total_displaced_by_conflict
# 0                                                    NaN
# 1                                                    NaN
# ...
