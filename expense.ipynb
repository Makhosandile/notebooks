# %%
import numpy as np
import pandas as pd

# %%
deficit_df = pd.read_csv("expense.csv")

# %%
def compensation_of_empl_perc_expense():
    """Compensation of employees (% of expense) [GC.XPN.COMP.ZS]"""
    df = deficit_df[["year", "country", "compensation_of_empl_perc_expense"]]
    return df

# %%
compensation_of_empl_perc_expense()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        compensation_of_empl_perc_expense
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# ...

# %%
def compensation_of_empl_currentLCU():
    """Compensation of employees (current LCU) [GC.XPN.COMP.CN]"""
    df = deficit_df[["year", "country", "compensation_of_empl_currentLCU"]]
    return df

# %%
compensation_of_empl_currentLCU()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        compensation_of_empl_currentLCU
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# ...

# %%
def expense_percGDP():
    """Expense (% of GDP) [GC.XPN.TOTL.GD.ZS]"""
    df = deficit_df[["year", "country", "expense_percGDP"]]
    return df

# %%
expense_percGDP()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        expense_percGDP
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 13237              NaN
# ...

# %%
def expense_currentLCU():
    """Expense (current LCU) [GC.XPN.TOTL.CN]"""
    df = deficit_df[["year", "country", "expense_currentLCU"]]
    return df

# %%
expense_currentLCU()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        expense_currentLCU
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# ...

# %%
def goods_and_services_expense_perc_expense():
    """Goods and services expense (% of expense) [GC.XPN.GSRV.ZS]"""
    df = deficit_df[["year", "country", "goods_and_services_expense_perc_expense"]]
    return df

# %%
goods_and_services_expense_perc_expense()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        goods_and_services_expense_perc_expense
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# ...

# %%
def goods_and_services_expense_currentLCU():
    """Goods and services expense (current LCU) [GC.XPN.GSRV.CN]"""
    df = deficit_df[["year", "country", "goods_and_services_expense_currentLCU"]]
    return df

# %%
goods_and_services_expense_currentLCU()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        goods_and_services_expense_currentLCU
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# ...

# %%
def interest_payments_perc_expense():
    """Interest payments (% of expense) [GC.XPN.INTP.ZS]"""
    df = deficit_df[["year", "country", "interest_payments_perc_expense"]]
    return df

# %%
interest_payments_perc_expense()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        interest_payments_perc_expense
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# ...

# %%
def interest_payments_perc_revenue():
    """Interest payments (% of revenue) [GC.XPN.INTP.RV.ZS]"""
    df = deficit_df[["year", "country", "interest_payments_perc_revenue"]]
    return df

# %%
interest_payments_perc_revenue()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        interest_payments_perc_revenue
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# ...

# %%
def interest_payments_currentLCU():
    """Interest payments (current LCU) [GC.XPN.INTP.CN]"""
    df = deficit_df[["year", "country", "interest_payments_currentLCU"]]
    return df

# %%
interest_payments_currentLCU()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        interest_payments_currentLCU
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# ...

# %%
def other_expense_perc_expense():
    """Other expense (% of expense) [GC.XPN.OTHR.ZS]"""
    df = deficit_df[["year", "country", "other_expense_perc_expense"]]
    return df

# %%
other_expense_perc_expense()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        other_expense_perc_expense
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# ...

# %%
def other_expense_currentLCU():
    """Other expense (current LCU) [GC.XPN.OTHR.CN]"""
    df = deficit_df[["year", "country", "other_expense_currentLCU"]]
    return df

# %%
other_expense_currentLCU()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        other_expense_currentLCU
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# ...

# %%
def subsidies_and_other_transfers_perc_expense():
    """Subsidies and other transfers (% of expense) [GC.XPN.TRFT.ZS]"""
    df = deficit_df[["year", "country", "subsidies_and_other_transfers_perc_expense"]]
    return df

# %%
subsidies_and_other_transfers_perc_expense()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        subsidies_and_other_transfers_perc_expense
# 0                                             NaN
# 1                                             NaN
# ...

# %%
def subsidies_and_other_transfers_currentLCU():
    """Subsidies and other transfers (current LCU) [GC.XPN.TRFT.CN]"""
    df = deficit_df[["year", "country", "subsidies_and_other_transfers_currentLCU"]]
    return df

# %%
subsidies_and_other_transfers_currentLCU()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        subsidies_and_other_transfers_currentLCU
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# ...
