# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns
import plotly.express as px
# import theme

# %matplotlib inline

# %%
df = pd.read_csv('empl.csv')
df
# Out:
#                                                    year Time Code  \
# 0                                                  1960    YR1960
# 1                                                  1960    YR1960
# 2                                                  1960    YR1960
# 3                                                  1960    YR1960
# 4                                                  1960    YR1960
# ...                                                 ...       ...
# 16226                                               NaN       NaN
# 16227                                               NaN       NaN
# 16228                                               NaN       NaN
# 16229  Data from database: World Development Indicators       NaN
# 16230                          Last Updated: 12/16/2021       NaN
#
#               country Country Code  youth  male_youth  \
# 0         Afghanistan          AFG    NaN         NaN
# 1             Albania          ALB    NaN         NaN
# 2             Algeria          DZA    NaN         NaN
# 3      American Samoa          ASM    NaN         NaN
# 4             Andorra          AND    NaN         NaN
# ...               ...          ...    ...         ...
# 16226             NaN          NaN    NaN         NaN
# 16227             NaN          NaN    NaN         NaN
# 16228             NaN          NaN    NaN         NaN
# 16229             NaN          NaN    NaN         NaN
# 16230             NaN          NaN    NaN         NaN
#
#        Unemployment, youth total (% of total labor force ages 15-24) (modeled ILO estimate) [SL.UEM.1524.ZS]  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 16226                                                NaN
# 16227                                                NaN
# 16228                                                NaN
# 16229                                                NaN
# 16230                                                NaN
#
#        Unemployment, youth male (% of male labor force ages 15-24) (modeled ILO estimate) [SL.UEM.1524.MA.ZS]  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 16226                                                NaN
# 16227                                                NaN
# 16228                                                NaN
# 16229                                                NaN
# 16230                                                NaN
#
#        female_youth  total_unemployement  ...  \
# 0               NaN                  NaN  ...
# 1               NaN                  NaN  ...
# 2               NaN                  NaN  ...
# 3               NaN                  NaN  ...
# 4               NaN                  NaN  ...
# ...             ...                  ...  ...
# 16226           NaN                  NaN  ...
# 16227           NaN                  NaN  ...
# 16228           NaN                  NaN  ...
# 16229           NaN                  NaN  ...
# 16230           NaN                  NaN  ...
#
#        Unemployment, female (% of female labor force) (modeled ILO estimate) [SL.UEM.TOTL.FE.ZS]  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 16226                                                NaN
# 16227                                                NaN
# 16228                                                NaN
# 16229                                                NaN
# 16230                                                NaN
#
#        male_intermediate_education  female_intermediate_education  \
# 0                              NaN                            NaN
# 1                              NaN                            NaN
# 2                              NaN                            NaN
# 3                              NaN                            NaN
# 4                              NaN                            NaN
# ...                            ...                            ...
# 16226                          NaN                            NaN
# 16227                          NaN                            NaN
# 16228                          NaN                            NaN
# 16229                          NaN                            NaN
# 16230                          NaN                            NaN
#
#        Unemployment with intermediate education (% of total labor force with intermediate education) [SL.UEM.INTM.ZS]  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 16226                                                NaN
# 16227                                                NaN
# 16228                                                NaN
# 16229                                                NaN
# 16230                                                NaN
#
#        male_basic_education  female_basic_education  \
# 0                       NaN                     NaN
# 1                       NaN                     NaN
# 2                       NaN                     NaN
# 3                       NaN                     NaN
# 4                       NaN                     NaN
# ...                     ...                     ...
# 16226                   NaN                     NaN
# 16227                   NaN                     NaN
# 16228                   NaN                     NaN
# 16229                   NaN                     NaN
# 16230                   NaN                     NaN
#
#        unemployement_basic_education  male_advanced_education  \
# 0                                NaN                      NaN
# 1                                NaN                      NaN
# 2                                NaN                      NaN
# 3                                NaN                      NaN
# 4                                NaN                      NaN
# ...                              ...                      ...
# 16226                            NaN                      NaN
# 16227                            NaN                      NaN
# 16228                            NaN                      NaN
# 16229                            NaN                      NaN
# 16230                            NaN                      NaN
#
#        female_advanced_education  unemployement_advanced_education
# 0                            NaN                               NaN
# 1                            NaN                               NaN
# 2                            NaN                               NaN
# 3                            NaN                               NaN
# 4                            NaN                               NaN
# ...                          ...                               ...
# 16226                        NaN                               NaN
# 16227                        NaN                               NaN
# 16228                        NaN                               NaN
# 16229                        NaN                               NaN
# 16230                        NaN                               NaN
#
# [16231 rows x 25 columns]

# %%
mdf = df.query(['country=="Afghanistan", "India", "Bangladesh", "Pakistan", "Sri Lanka", "Maldives", "Bhutan", "Nepal"'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-aaae17df210e> in <module>
# ----> 1 mdf = df.query(['country=="Afghanistan", "India", "Bangladesh", "Pakistan", "Sri Lanka", "Maldives", "Bhutan", "Nepal"'])
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in query(self, expr, inplace, **kwargs)
#    4050         if not isinstance(expr, str):
#    4051             msg = f"expr must be a string to be evaluated, {type(expr)} given"
# -> 4052             raise ValueError(msg)
#    4053         kwargs["level"] = kwargs.pop("level", 0) + 1
#    4054         kwargs["target"] = None
#
# ValueError: expr must be a string to be evaluated, <class 'list'> given

# %%
m.to_csv('aa.csv')
