# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('country.csv')

# %%
df.head()
# Out:
#   country_code                                long_name         income_group  \
# 0          AFG             Islamic State of Afghanistan           Low income
# 1          ALB                      Republic of Albania  Upper middle income
# 2          DZA  People's Democratic Republic of Algeria  Lower middle income
# 3          ASM                           American Samoa  Upper middle income
# 4          AND                  Principality of Andorra          High income
#
#                        region lending_category   currency_unit         country
# 0                  South Asia              IDA  Afghan afghani     Afghanistan
# 1       Europe & Central Asia             IBRD    Albanian lek         Albania
# 2  Middle East & North Africa             IBRD  Algerian dinar         Algeria
# 3         East Asia & Pacific              NaN     U.S. dollar  American Samoa
# 4       Europe & Central Asia              NaN            Euro         Andorra

# %%
def south_asia():
    data = df.query('region == "South Asia"')
    # data = df[['country_code', 'income_group', 'lending_category', 'other_groups', 'currency_unit', 'country', ]]
    return data
south_asia()
# Out:
#     country_code                                   long_name  \
# 0            AFG                Islamic State of Afghanistan
# 15           BGD             People's Republic of Bangladesh
# 22           BTN                           Kingdom of Bhutan
# 89           IND                           Republic of India
# 121          MDV                        Republic of Maldives
# 138          NPL                                       Nepal
# 149          PAK                Islamic Republic of Pakistan
# 180          LKA  Democratic Socialist Republic of Sri Lanka
#
#             income_group      region lending_category       currency_unit  \
# 0             Low income  South Asia              IDA      Afghan afghani
# 15   Lower middle income  South Asia              IDA    Bangladeshi taka
# 22   Lower middle income  South Asia              IDA  Bhutanese ngultrum
# 89   Lower middle income  South Asia             IBRD        Indian rupee
# ...

# %%
def eu_and_central_asia():
    data = df.query('region == "Europe & Central Asia"')
    # data = df[['country_code', 'income_group', 'lending_category', 'other_groups', 'currency_unit', 'country', ]]
    return data
eu_and_central_asia().head()
# Out:
#    country_code                long_name         income_group  \
# 1           ALB      Republic of Albania  Upper middle income
# 4           AND  Principality of Andorra          High income
# 8           ARM      Republic of Armenia  Upper middle income
# 11          AUT      Republic of Austria          High income
# 12          AZE   Republic of Azerbaijan  Upper middle income
#
#                    region lending_category    currency_unit     country
# 1   Europe & Central Asia             IBRD     Albanian lek     Albania
# 4   Europe & Central Asia              NaN             Euro     Andorra
# 8   Europe & Central Asia             IBRD    Armenian dram     Armenia
# 11  Europe & Central Asia              NaN             Euro     Austria
# 12  Europe & Central Asia             IBRD  New Azeri manat  Azerbaijan

# %%
def middle_east_and_north_africa():
    data = df.query('region == "Middle East & North Africa"')
    return data
middle_east_and_north_africa().tail()
# Out:
#     country_code             long_name         income_group  \
# 189          SYR  Syrian Arab Republic           Low income
# 197          TUN   Republic of Tunisia  Lower middle income
# 204          ARE  United Arab Emirates          High income
# 213          PSE    West Bank and Gaza  Lower middle income
# 214          YEM     Republic of Yemen           Low income
#
#                          region lending_category       currency_unit  \
# 189  Middle East & North Africa              IDA        Syrian pound
# 197  Middle East & North Africa             IBRD      Tunisian dinar
# 204  Middle East & North Africa              NaN       U.A.E. dirham
# 213  Middle East & North Africa              NaN  Israeli new shekel
# 214  Middle East & North Africa              IDA         Yemeni rial
#
#                   country
# 189  Syrian Arab Republic
# 197               Tunisia
# 204  United Arab Emirates
# 213    West Bank and Gaza
# 214                 Yemen

# %%
def east_asia_and_pacific():
    data = df.query('region == "East Asia & Pacific"')
    return data
east_asia_and_pacific().head()
# Out:
#    country_code                   long_name         income_group  \
# 3           ASM              American Samoa  Upper middle income
# 10          AUS   Commonwealth of Australia          High income
# 28          BRN           Brunei Darussalam          High income
# 33          KHM         Kingdom of Cambodia  Lower middle income
# 41          CHN  People's Republic of China  Upper middle income
#
#                  region lending_category      currency_unit         country
# 3   East Asia & Pacific              NaN        U.S. dollar  American Samoa
# 10  East Asia & Pacific              NaN  Australian dollar       Australia
# 28  East Asia & Pacific              NaN      Brunei dollar          Brunei
# 33  East Asia & Pacific              IDA     Cambodian riel        Cambodia
# 41  East Asia & Pacific             IBRD       Chinese yuan           China

# %%
def sub_saharan_africa():
    data = df.query('region == "Sub-Saharan Africa"')
    return data
sub_saharan_africa().head()
# Out:
#    country_code                    long_name         income_group  \
# 5           AGO  People's Republic of Angola  Lower middle income
# 20          BEN            Republic of Benin  Lower middle income
# 25          BWA         Republic of Botswana  Upper middle income
# 30          BFA                 Burkina Faso           Low income
# 31          BDI          Republic of Burundi           Low income
#
#                 region lending_category           currency_unit       country
# 5   Sub-Saharan Africa             IBRD          Angolan kwanza        Angola
# 20  Sub-Saharan Africa              IDA  West African CFA franc         Benin
# 25  Sub-Saharan Africa             IBRD           Botswana pula      Botswana
# 30  Sub-Saharan Africa              IDA  West African CFA franc  Burkina Faso
# 31  Sub-Saharan Africa              IDA           Burundi franc       Burundi

# %%
def lac():
    data = df.query('region == "Latin America & Caribbean"')
    return data
lac().head()
# Out:
#    country_code                    long_name         income_group  \
# 6           ATG          Antigua and Barbuda          High income
# 7           ARG           Argentine Republic  Upper middle income
# 9           ABW                        Aruba          High income
# 13          BHS  Commonwealth of The Bahamas          High income
# 16          BRB                     Barbados          High income
#
#                        region lending_category          currency_unit  \
# 6   Latin America & Caribbean             IBRD  East Caribbean dollar
# 7   Latin America & Caribbean             IBRD         Argentine peso
# 9   Latin America & Caribbean              NaN          Aruban florin
# 13  Latin America & Caribbean              NaN        Bahamian dollar
# 16  Latin America & Caribbean              NaN        Barbados dollar
#
#                 country
# 6   Antigua and Barbuda
# 7             Argentina
# 9                 Aruba
# 13          The Bahamas
# ...

# %%
def north_america():
    data = df.query('region == "North America"')
    return data
north_america().head()
# Out:
#     country_code                 long_name income_group         region  \
# 21           BMU              The Bermudas  High income  North America
# 35           CAN                    Canada  High income  North America
# 206          USA  United States of America  High income  North America
#
#     lending_category    currency_unit        country
# 21               NaN   Bermuda dollar        Bermuda
# 35               NaN  Canadian dollar         Canada
# 206              NaN      U.S. dollar  United States

# %% [markdown]
# ### INCOME LEVELS

# %%
def low_income():
    data = df.query('income_group == "Low income"')
    return data
low_income().tail()
# Out:
#     country_code              long_name income_group  \
# 185          SDN  Republic of the Sudan   Low income
# 189          SYR   Syrian Arab Republic   Low income
# 194          TGO       Republic of Togo   Low income
# 202          UGA     Republic of Uganda   Low income
# 214          YEM      Republic of Yemen   Low income
#
#                          region lending_category           currency_unit  \
# 185          Sub-Saharan Africa              IDA          Sudanese pound
# 189  Middle East & North Africa              IDA            Syrian pound
# 194          Sub-Saharan Africa              IDA  West African CFA franc
# 202          Sub-Saharan Africa              IDA        Ugandan shilling
# 214  Middle East & North Africa              IDA             Yemeni rial
#
#                   country
# 185                 Sudan
# 189  Syrian Arab Republic
# 194                  Togo
# 202                Uganda
# 214                 Yemen

# %%
def upper_middle_income():
    data = df.query('income_group == "Upper middle income"')
    return data
low_income().head()
# Out:
#    country_code                     long_name income_group  \
# 0           AFG  Islamic State of Afghanistan   Low income
# 30          BFA                  Burkina Faso   Low income
# 31          BDI           Republic of Burundi   Low income
# 37          CAF      Central African Republic   Low income
# 38          TCD              Republic of Chad   Low income
#
#                 region lending_category              currency_unit  \
# 0           South Asia              IDA             Afghan afghani
# 30  Sub-Saharan Africa              IDA     West African CFA franc
# 31  Sub-Saharan Africa              IDA              Burundi franc
# 37  Sub-Saharan Africa              IDA  Central African CFA franc
# 38  Sub-Saharan Africa              IDA  Central African CFA franc
#
#                      country
# 0                Afghanistan
# 30              Burkina Faso
# 31                   Burundi
# 37  Central African Republic
# 38                      Chad

# %%
def lower_middle_income():
    data = df.query('income_group == "Lower middle income"')
    return data
lower_middle_income()
# Out:
#     country_code                                     long_name  \
# 2            DZA       People's Democratic Republic of Algeria
# 5            AGO                   People's Republic of Angola
# 15           BGD               People's Republic of Bangladesh
# 19           BLZ                                        Belize
# 20           BEN                             Republic of Benin
# 22           BTN                             Kingdom of Bhutan
# 23           BOL                Plurinational State of Bolivia
# 32           CPV                        Republic of Cabo Verde
# 33           KHM                           Kingdom of Cambodia
# 34           CMR                          Republic of Cameroon
# 43           COM                          Union of the Comoros
# 45           COG                             Republic of Congo
# 47           CIV                     Republic of Côte d'Ivoire
# 54           DJI                          Republic of Djibouti
# ...

# %%
def high_income():
    data = df.query('income_group == "High income"')
    return data
high_income()
# Out:
#     country_code                                          long_name  \
# 4            AND                            Principality of Andorra
# 6            ATG                                Antigua and Barbuda
# 9            ABW                                              Aruba
# 10           AUS                          Commonwealth of Australia
# 11           AUT                                Republic of Austria
# ..           ...                                                ...
# 204          ARE                               United Arab Emirates
# 205          GBR  United Kingdom of Great Britain and Northern I...
# 206          USA                           United States of America
# 207          URY                       Oriental Republic of Uruguay
# 212          VIR                Virgin Islands of the United States
#
#     income_group                      region lending_category  \
# 4    High income       Europe & Central Asia              NaN
# ...

# %%
def not_classified():
    data = df.query('income_group == "Not classified"')
    return data
not_classified()
# Out:
# Empty DataFrame
# Columns: [country_code, long_name, income_group, region, lending_category, currency_unit, country]
# Index: []

# %%
def not_classified():
    data = df.query('country == "South Africa"')
    return data
not_classified()
# Out:
#     country_code                 long_name         income_group  \
# 177          ZAF  Republic of South Africa  Upper middle income
#
#                  region lending_category       currency_unit       country
# 177  Sub-Saharan Africa             IBRD  South African rand  South Africa

# %%
def zar():
    data = df.query('currency_unit == "South African rand"')
    return data
zar()
# Out:
#     country_code                 long_name         income_group  \
# 177          ZAF  Republic of South Africa  Upper middle income
#
#                  region lending_category       currency_unit       country
# 177  Sub-Saharan Africa             IBRD  South African rand  South Africa

# %%
def zar():
    data = df.query('currency_unit == "U.S. dollar"')
    return data
zar()
# Out:
#     country_code                                     long_name  \
# 3            ASM                                American Samoa
# 27           VGB                        British Virgin Islands
# 57           ECU                           Republic of Ecuador
# 59           SLV                       Republic of El Salvador
# 79           GUM                                          Guam
# 112          LBR                           Republic of Liberia
# 124          MHL              Republic of the Marshall Islands
# 128          FSM                Federated States of Micronesia
# 146          MNP  Commonwealth of the Northern Mariana Islands
# 150          PLW                             Republic of Palau
# 158          PRI                                   Puerto Rico
# 193          TLS            Democratic Republic of Timor-Leste
# 200          TCA                      Turks and Caicos Islands
# 206          USA                      United States of America
# ...
