# %%
! pip install pandas
! pip install numpy
! pip install dash

# %%
import pandas as pd
from dash import Dash, Input, Output, dcc, html

# %%
sa_df = pd.read_csv('sa.csv')

# %%
sa_df.head()
# Out:
#      year year_code      country country_code   gdp_current  agriculture  \
# 0  1960.0    YR1960  Afghanistan          AFG  5.377778e+08          NaN
# 1  1960.0    YR1960   Bangladesh          BGD  4.274894e+09          NaN
# 2  1960.0    YR1960       Bhutan          BTN           NaN          NaN
# 3  1960.0    YR1960        India          IND  3.702988e+10          NaN
# 4  1960.0    YR1960     Maldives          MDV           NaN          NaN
#
#    exports  final_exp  gdp_growth  gdp_per_capita  ...  gni_growth_capita  \
# 0      NaN        NaN         NaN             NaN  ...                NaN
# 1      NaN        NaN         NaN             NaN  ...                NaN
# 2      NaN        NaN         NaN             NaN  ...                NaN
# 3      NaN        NaN         NaN             NaN  ...                NaN
# 4      NaN        NaN         NaN             NaN  ...                NaN
#
#    gni_growth  gross_capital_formation  gross_fixed_capital_formation  \
# ...

# %%
af = sa_df.query('country == "Afghanistan"')

# %%
af
# Out:
#        year year_code      country country_code   gdp_current  agriculture  \
# 0    1960.0    YR1960  Afghanistan          AFG  5.377778e+08          NaN
# 8    1961.0    YR1961  Afghanistan          AFG  5.488889e+08          NaN
# 16   1962.0    YR1962  Afghanistan          AFG  5.466667e+08          NaN
# 24   1963.0    YR1963  Afghanistan          AFG  7.511112e+08          NaN
# 32   1964.0    YR1964  Afghanistan          AFG  8.000000e+08          NaN
# ..      ...       ...          ...          ...           ...          ...
# 456  2017.0    YR2017  Afghanistan          AFG  1.889635e+10     6.411059
# 464  2018.0    YR2018  Afghanistan          AFG  1.841885e+10    -4.415311
# 472  2019.0    YR2019  Afghanistan          AFG  1.890449e+10    17.459825
# 480  2020.0    YR2020  Afghanistan          AFG  2.014344e+10     5.942340
# 488  2021.0    YR2021  Afghanistan          AFG  1.478686e+10    -2.833169
#
# ...
