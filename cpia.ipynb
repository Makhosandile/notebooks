# %%
import numpy as np
import pandas as pd

# %%
deficit_df = pd.read_csv("cpia.csv")

# %%
def building_hr_rating():
    """CPIA building human resources rating (1=low to 6=high) [IQ.CPA.HRES.XQ]"""
    df = deficit_df[["year", "country", "building_hr_rating"]]
    return df

# %%
building_hr_rating()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        building_hr_rating
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# ...

# %%
def business_regulatory_env_rating():
    """CPIA business regulatory environment rating (1=low to 6=high) [IQ.CPA.BREG.XQ]"""
    df = deficit_df[["year", "country", "business_regulatory_env_rating"]]
    return df

# %%
business_regulatory_env_rating()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        business_regulatory_env_rating
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# ...

# %%
def debt_policy_rating():
    """CPIA debt policy rating (1=low to 6=high) [IQ.CPA.DEBT.XQ]"""
    df = deficit_df[["year", "country", "debt_policy_rating"]]
    return df

# %%
debt_policy_rating()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        debt_policy_rating
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# ...

# %%
def economic_management_cluster_average():
    """CPIA economic management cluster average (1=low to 6=high) [IQ.CPA.ECON.XQ]"""
    df = deficit_df[["year", "country", "economic_management_cluster_average"]]
    return df

# %%
economic_management_cluster_average()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        economic_management_cluster_average
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# ...

# %%
def efficiency_revenue_mobilization_rating():
    """CPIA efficiency of revenue mobilization rating (1=low to 6=high) [IQ.CPA.REVN.XQ]"""
    df = deficit_df[["year", "country", "efficiency_revenue_mobilization_rating"]]
    return df

# %%
efficiency_revenue_mobilization_rating()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        efficiency_revenue_mobilization_rating
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# ...

# %%
def equity_public_resource_use():
    """CPIA equity of public resource use rating (1=low to 6=high) [IQ.CPA.PRES.XQ]"""
    df = deficit_df[["year", "country", "equity_public_resource_use"]]
    return df

# %%
equity_public_resource_use()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        equity_public_resource_use
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# ...

# %%
def financial_sector_rating():
    """CPIA financial sector rating (1=low to 6=high) [IQ.CPA.FINS.XQ]"""
    df = deficit_df[["year", "country", "financial_sector_rating"]]
    return df

# %%
financial_sector_rating()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        financial_sector_rating
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...

# %%
def fiscal_policy_rating():
    """CPIA fiscal policy rating (1=low to 6=high) [IQ.CPA.FISP.XQ]"""
    df = deficit_df[["year", "country", "fiscal_policy_rating"]]
    return df

# %%
fiscal_policy_rating()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        fiscal_policy_rating
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ...

# %%
def gender_equality_rating():
    """CPIA gender equality rating (1=low to 6=high) [IQ.CPA.GNDR.XQ]"""
    df = deficit_df[["year", "country", "gender_equality_rating"]]
    return df

# %%
gender_equality_rating()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        gender_equality_rating
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...

# %%
def macroeconomic_management_rating():
    """CPIA macroeconomic management rating (1=low to 6=high) [IQ.CPA.MACR.XQ]"""
    df = deficit_df[["year", "country", "macroeconomic_management_rating"]]
    return df

# %%
macroeconomic_management_rating()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        macroeconomic_management_rating
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# ...

# %%
def policies_social_inclusion_equity_cluster_average():
    """CPIA policies for social inclusion/equity cluster average (1=low to 6=high) [IQ.CPA.SOCI.XQ]"""
    df = deficit_df[["year", "country", "policies_social_inclusion_equity_cluster_average"]]
    return df

# %%
policies_social_inclusion_equity_cluster_average()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        policies_social_inclusion_equity_cluster_average
# 0                                                   NaN
# 1                                                   NaN
# ...

# %%
def policy_institutions_environmental_sustainability_rating():
    """CPIA policy and institutions for environmental sustainability rating (1=low to 6=high) [IQ.CPA.ENVR.XQ]"""
    df = deficit_df[["year", "country", "policy_institutions_environmental_sustainability_rating"]]
    return df

# %%
policy_institutions_environmental_sustainability_rating()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        policy_institutions_environmental_sustainability_rating
# 0                                                    NaN
# 1                                                    NaN
# ...

# %%
def property_rights_and_rulebased_governance_rating():
    """CPIA property rights and rule-based governance rating (1=low to 6=high) [IQ.CPA.PROP.XQ]"""
    df = deficit_df[["year", "country", "property_rights_and_rulebased_governance_rating"]]
    return df

# %%
property_rights_and_rulebased_governance_rating()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        property_rights_and_rulebased_governance_rating
# 0                                                  NaN
# 1                                                  NaN
# ...

# %%
def public_sector_management_and_institutions_cluster_average():
    """CPIA public sector management and institutions cluster average (1=low to 6=high) [IQ.CPA.PUBS.XQ]"""
    df = deficit_df[["year", "country", "public_sector_management_and_institutions_cluster_average"]]
    return df

# %%
public_sector_management_and_institutions_cluster_average()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        public_sector_management_and_institutions_cluster_average
# 0                                                    NaN
# 1                                                    NaN
# ...

# %%
def quality_budgetary_and_financial_management_rating():
    """TCPIA quality of budgetary and financial management rating (1=low to 6=high) [IQ.CPA.FINQ.XQ]"""
    df = deficit_df[["year", "country", "quality_budgetary_and_financial_management_rating"]]
    return df

# %%
quality_budgetary_and_financial_management_rating()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        quality_budgetary_and_financial_management_rating
# 0                                                    NaN
# 1                                                    NaN
# ...

# %%
def quality_of_public_administration_rating():
    """CPIA quality of public administration rating (1=low to 6=high) [IQ.CPA.PADM.XQ]"""
    df = deficit_df[["year", "country", "quality_of_public_administration_rating"]]
    return df

# %%
quality_of_public_administration_rating()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        quality_of_public_administration_rating
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# ...

# %%
def social_protection_rating():
    """CPIA social protection rating (1=low to 6=high) [IQ.CPA.PROT.XQ]"""
    df = deficit_df[["year", "country", "social_protection_rating"]]
    return df

# %%
social_protection_rating()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        social_protection_rating
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# ...

# %%
def structural_policies_cluster_average():
    """CPIA structural policies cluster average (1=low to 6=high) [IQ.CPA.STRC.XQ]"""
    df = deficit_df[["year", "country", "structural_policies_cluster_average"]]
    return df

# %%
structural_policies_cluster_average()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        structural_policies_cluster_average
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# ...

# %%
def trade_rating():
    """CPIA trade rating (1=low to 6=high) [IQ.CPA.TRAD.XQ]"""
    df = deficit_df[["year", "country", "trade_rating"]]
    return df

# %%
trade_rating()
# Out:
#          year                                           country  trade_rating
# 0      1960.0                                       Afghanistan           NaN
# 1      1961.0                                       Afghanistan           NaN
# 2      1962.0                                       Afghanistan           NaN
# 3      1963.0                                       Afghanistan           NaN
# 4      1964.0                                       Afghanistan           NaN
# ...       ...                                               ...           ...
# 13237     NaN                                               NaN           NaN
# 13238     NaN                                               NaN           NaN
# 13239     NaN                                               NaN           NaN
# 13240     NaN  Data from database: World Development Indicators           NaN
# 13241     NaN                          Last Updated: 09/15/2021           NaN
#
# [13242 rows x 3 columns]

# %%
def transparency_accountability_corruption_inthe_public_sector_rating():
    """CPIA transparency, accountability, and corruption in the public sector rating (1=low to 6=high) [IQ.CPA.TRAN.XQ]"""
    df = deficit_df[["year", "country", "transparency_accountability_corruption_inthe_public_sector_rating"]]
    return df

# %%
transparency_accountability_corruption_inthe_public_sector_rating()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        transparency_accountability_corruption_inthe_public_sector_rating
# 0                                                    NaN
# 1                                                    NaN
# ...

# %%
def human_capital_index():
    """Human capital index (HCI) (scale 0-1) [HD.HCI.OVRL]"""
    df = deficit_df[["year", "country", "human_capital_index"]]
    return df

# %%
human_capital_index()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        human_capital_index
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# ...

# %%
def human_capital_index_female():
    """Human capital index (HCI), female (scale 0-1) [HD.HCI.OVRL.FE]"""
    df = deficit_df[["year", "country", "human_capital_index_female"]]
    return df

# %%
human_capital_index_female()
# Out:
#          year                                           country  \
# 0      1960.0                                       Afghanistan
# 1      1961.0                                       Afghanistan
# 2      1962.0                                       Afghanistan
# 3      1963.0                                       Afghanistan
# 4      1964.0                                       Afghanistan
# ...       ...                                               ...
# 13237     NaN                                               NaN
# 13238     NaN                                               NaN
# 13239     NaN                                               NaN
# 13240     NaN  Data from database: World Development Indicators
# 13241     NaN                          Last Updated: 09/15/2021
#
#        human_capital_index_female
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# ...
