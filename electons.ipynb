# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('national.csv')

# %%
df
# Out:
#                                         party_name ward_valid_votes  \
# 0               ABAHLALI BASE MKHANYAKUDE MOVEMENT            1,042
# 1                                   ABAHLALY BAAHI              202
# 2                            ABANTU BATHO CONGRESS           39,010
# 3                        ABANTU INTEGRITY MOVEMENT            2,758
# 4                                  ABLE LEADERSHIP            3,368
# ..                                             ...              ...
# 319                               WITZENBERG PARTY              373
# 320                                   XIMOKO PARTY              804
# 321                            YOUNG PEOPLES PARTY               58
# 322  YOUTH INDEPENDENCE PARTY AND YOUTH ASSOCIATES              197
# 323                            ZULU ROYAL PROPERTY                1
#
#     ward_valid_votes_perc provincial_valid_votes provincial_valid_votes_perc  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 324 entries, 0 to 323
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   party_name                   324 non-null    object
#  1   ward_valid_votes             324 non-null    object
#  2   ward_valid_votes_perc        324 non-null    object
#  3   provincial_valid_votes       324 non-null    object
#  4   provincial_valid_votes_perc  324 non-null    object
#  5   combined_total               324 non-null    object
#  6   combined_total_perc          324 non-null    object
#  7   total_valid_votes            324 non-null    object
#  8   total_valid_votes_perc       324 non-null    object
#  9   overal_valid_votes           324 non-null    object
#  10  overal_valid_votes.1         324 non-null    object
# dtypes: object(11)
# memory usage: 28.0+ KB

# %%
df = int('ward_valid_votes')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-75d7532dd9b3> in <module>
# ----> 1 df = int('ward_valid_votes')
#
# ValueError: invalid literal for int() with base 10: 'ward_valid_votes'
